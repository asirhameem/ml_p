# %%
import pandas as pd

totalRecords = pd.read_csv('TotalRecords.csv')
totalRecords
# Out:
#                id        date   time   33    34  35  36   48   57     58  ...  \
# 0      Patient 01  04-21-1991   9:09  NaN   NaN NaN NaN  NaN  NaN  100.0  ...
# 1      Patient 01  04-21-1991   9:09  9.0   NaN NaN NaN  NaN  NaN    NaN  ...
# 2      Patient 01  04-21-1991   9:09  NaN  13.0 NaN NaN  NaN  NaN    NaN  ...
# 3      Patient 01  04-21-1991  17:08  NaN   NaN NaN NaN  NaN  NaN    NaN  ...
# 4      Patient 01  04-21-1991  17:08  7.0   NaN NaN NaN  NaN  NaN    NaN  ...
# ...           ...         ...    ...  ...   ...  ..  ..  ...  ...    ...  ...
# 29325  Patient 70  05-09-1989  08:00  1.0   NaN NaN NaN  NaN  NaN    NaN  ...
# 29326  Patient 70  05-09-1989  08:00  NaN   7.0 NaN NaN  NaN  NaN    NaN  ...
# 29327  Patient 70  05-10-1989  08:00  NaN   7.0 NaN NaN  NaN  NaN    NaN  ...
# 29328  Patient 70  05-11-1989  08:00  NaN   7.0 NaN NaN  NaN  NaN    NaN  ...
# 29329  Patient 70  05-12-1989  08:00  NaN   7.0 NaN NaN  NaN  NaN    NaN  ...
#
# ...

# %%
newRec = totalRecords.groupby(['id', 'date', 'time']).first().reset_index()

# %%
newRec
# Out:
#                id        date   time   33    34  35  36     48   57     58  \
# 0      Patient 01  04-21-1991  17:08  7.0   NaN NaN NaN    NaN  NaN    NaN
# 1      Patient 01  04-21-1991  22:51  NaN   NaN NaN NaN  123.0  NaN    NaN
# 2      Patient 01  04-21-1991   9:09  9.0  13.0 NaN NaN    NaN  NaN  100.0
# 3      Patient 01  04-22-1991  13:40  2.0   NaN NaN NaN    NaN  NaN    NaN
# 4      Patient 01  04-22-1991  16:56  7.0   NaN NaN NaN    NaN  NaN    NaN
# ...           ...         ...    ...  ...   ...  ..  ..    ...  ...    ...
# 18332  Patient 70  05-08-1989  22:00  NaN   NaN NaN NaN  145.0  NaN    NaN
# 18333  Patient 70  05-09-1989  08:00  1.0   7.0 NaN NaN    NaN  NaN  259.0
# 18334  Patient 70  05-10-1989  08:00  NaN   7.0 NaN NaN    NaN  NaN    NaN
# 18335  Patient 70  05-11-1989  08:00  NaN   7.0 NaN NaN    NaN  NaN    NaN
# 18336  Patient 70  05-12-1989  08:00  NaN   7.0 NaN NaN    NaN  NaN    NaN
#
#        ...  63  64  65  66  67  68  69  70  71  72
# ...

# %%
newRec.to_csv(r'GroupedRecords.csv', index = False)
