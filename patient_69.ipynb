# %%
import csv

import pandas as pd

patient_69 = pd.read_csv('Diabetes-Data/data-69',sep='\t', names=['date', 'time', 'code', 'volume'])

code33 = patient_69[patient_69['code'] == 33]

code34 = patient_69[patient_69['code'] == 34]

code35 = patient_69[patient_69['code'] == 35]

code48 = patient_69[patient_69['code'] == 48]

code57 = patient_69[patient_69['code'] == 57]

code58 = patient_69[patient_69['code'] == 58]

code59 = patient_69[patient_69['code'] == 59]

code60 = patient_69[patient_69['code'] == 60]

code61 = patient_69[patient_69['code'] == 61]

code62 = patient_69[patient_69['code'] == 62]

code63 = patient_69[patient_69['code'] == 63]

code64 = patient_69[patient_69['code'] == 64]

code65 = patient_69[patient_69['code'] == 65]

code66 = patient_69[patient_69['code'] == 66]

code67 = patient_69[patient_69['code'] == 67]

code68 = patient_69[patient_69['code'] == 68]

code69 = patient_69[patient_69['code'] == 69]

code70 = patient_69[patient_69['code'] == 70]

code71 = patient_69[patient_69['code'] == 71]

code72 = patient_69[patient_69['code'] == 72]

code71

rec69 = pd.read_csv('PatientRecords.csv')

rec69

rec69['date'] = patient_69['date']

rec69['id'] = 'Patient 69'

rec69['time'] = patient_69['time']

rec69['33'] = code33['volume']

rec69['34'] = code34['volume']

rec69['35'] = code35['volume']

rec69['48'] = code48['volume']

rec69['57'] = code57['volume']

rec69['58'] = code58['volume']

rec69['59'] = code59['volume']

rec69['60'] = code60['volume']

rec69['61'] = code61['volume']

rec69['62'] = code62['volume']

rec69['63'] = code63['volume']

rec69['64'] = code64['volume']

rec69['65'] = code65['volume']

rec69['66'] = code66['volume']

rec69['67'] = code67['volume']

rec69['68'] = code68['volume']

rec69['69'] = code69['volume']

rec69['70']  = code70['volume']

rec69['71'] = code71['volume']

rec69['72'] = code72['volume']

rec69

patient_69

rec69.to_csv(r'Prec69.csv', index = False)

# %%
rec69
# Out:
#             id        date   time  33  34  35   36  48     57  58  ...     63  \
# 0   Patient 69  08-22-1990  08:58 NaN NaN NaN  NaN NaN  323.0 NaN  ...    NaN
# 1   Patient 69  08-22-1990  10:26 NaN NaN NaN  NaN NaN  319.0 NaN  ...    NaN
# 2   Patient 69  08-22-1990  18:25 NaN NaN NaN  NaN NaN  138.0 NaN  ...    NaN
# 3   Patient 69  08-22-1990  22:23 NaN NaN NaN  NaN NaN  110.0 NaN  ...    NaN
# 4   Patient 69  08-23-1990  21:14 NaN NaN NaN  NaN NaN  112.0 NaN  ...    NaN
# 5   Patient 69  08-24-1990  09:21 NaN NaN NaN  NaN NaN  281.0 NaN  ...    NaN
# 6   Patient 69  08-24-1990  13:02 NaN NaN NaN  NaN NaN    NaN NaN  ...    NaN
# 7   Patient 69  08-24-1990  18:15 NaN NaN NaN  NaN NaN   59.0 NaN  ...    NaN
# 8   Patient 69  08-24-1990  22:23 NaN NaN NaN  NaN NaN  251.0 NaN  ...    NaN
# 9   Patient 69  08-25-1990  07:37 NaN NaN NaN  NaN NaN  359.0 NaN  ...    NaN
# 10  Patient 69  08-25-1990  08:00 NaN NaN NaN  NaN NaN    NaN NaN  ...    NaN
# ...

# %%
patient_69
# Out:
#           date   time  code  volume
# 0   08-22-1990  08:58    57     323
# 1   08-22-1990  10:26    57     319
# 2   08-22-1990  18:25    57     138
# 3   08-22-1990  22:23    57     110
# 4   08-23-1990  21:14    57     112
# 5   08-24-1990  09:21    57     281
# 6   08-24-1990  13:02    56     258
# 7   08-24-1990  18:15    57      59
# 8   08-24-1990  22:23    57     251
# 9   08-25-1990  07:37    57     359
# 10  08-25-1990  08:00    56     130
# 11  08-25-1990  14:16    57     342
# 12  08-25-1990  20:56    57     344
# 13  08-25-1990  23:47    57     266
# 14  08-26-1990  07:56    63     242
# 15  08-26-1990  13:53    57     164
# 16  08-26-1990  18:17    57     161
# 17  08-26-1990  21:42    57     151
# 18  08-27-1990  06:25    57     130
# 19  08-27-1990  14:06    57     326
# 20  08-27-1990  17:38    57     126
# 21  08-27-1990  22:41    57     190
# 22  08-28-1990  08:06    57     265
# 23  08-28-1990  13:59    57     220
# 24  08-28-1990  16:46    57     117
# ...
